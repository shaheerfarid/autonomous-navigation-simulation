# %% [markdown]
# # Autonomous Navigation Experiments
#
# Use this notebook to experiment with model parameters, visualize dataset samples, and test individual components of the perception-planning-control pipeline.

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2

# Add src to path
sys.path.append("../src")

from learning.model import get_model
from utils.video import video_to_np

# %% [markdown]
# ## Quick Visualization
# Load some data and visualize it.

# %%
# Example: visualize a frame from a video
video_path = '../dataset/video1.MOV'
if os.path.exists(video_path):
    frames, labels = video_to_np(video_path)
    plt.imshow(frames[0], cmap='gray')
    plt.title(f"Label: {labels[0]}")
    plt.show()
else:
    print("Dataset not found at expected path.")
